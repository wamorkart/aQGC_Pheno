# %%
import matplotlib.pyplot as plt

# %%
indir = "/eos/user/t/twamorka/aQGC_Pheno/"
process = "sswwjj"
operator = "S0"

vals = [1e-11,2e-11,3e-11,4e-11,5e-11,6e-11,7e-11,8e-11,9e-11,1e-10]

# %%
XS_vals = []
for val in vals:

    f_in = indir + "cross_section_"+process+"_"+operator+"_"+str(val)+".txt"
#     print (f_in)
    with open(f_in) as f:
        lines = f.readlines()
#         for line in (lines[1]):
#             prit 
        XS_vals.append(lines[1].split()[2])

# %%
print (XS_vals)
# Out:
# ['0.0121187687536', '0.0134628504934', '0.0162041198375', '0.0225218663078', '0.0296462189659', '0.0358777574658', '0.0445553952437', '0.057387402927', '0.0701063563715', '0.0732070117092']

# %%
plt.plot(vals, XS_vals,'ro')
